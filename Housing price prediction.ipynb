# %% [markdown]
# # check for coeff

# %% [markdown]
# analyticsvidhya.com/blog/2017/06/a-comprehensive-guide-for-linear-ridge-and-lasso-regression/

# %%
import pandas as pd
import numpy as np

#DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#Importing warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### importing train dataset

# %%
df=pd.read_csv('housing_train.csv')
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2007        WD         Normal     128000
# 1        10   2007        WD         Normal     268000
# 2         6   2007        WD         Normal     269790
# 3         1   2010       COD         Normal     190000
# 4         6   2009        WD         Normal     215000
# ...     ...    ...       ...            ...        ...
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [1168 rows x 81 columns]

# %%
#checking shape of dataset
shape=df.shape
print("\nTotal Number of Rows : ",shape[0])
print("Total Number of Features : ", shape[1])
# Out:
# Total Number of Rows :  1168
# Total Number of Features :  81

# %% [markdown]
# The given dataset contains 1168 rows & 81 column

# %%
#checking the features .ie column names
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#checking the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1161 non-null   object
#  26  MasVnrArea     1161 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1168 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    617 non-null    object
#  58  GarageType     1104 non-null   object
#  59  GarageYrBlt    1104 non-null   float64
#  60  GarageFinish   1104 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1104 non-null   object
#  64  GarageCond     1104 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          237 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
#  80  SalePrice      1168 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 739.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#checking data types of each column
print(df.columns.groupby(df.dtypes))
# Out:
# {int64: ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'], float64: ['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], object: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']}

# %%
#checking for null values
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# It means  null values are present in our dataset

# %%
#checking for null values in each column
print("Total number of empty rows in each feature:\n", df.isnull().sum())
# Out:
# Total number of empty rows in each feature:
#  Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# We can also see it via visualization with the help of heatmap

# %%
#visualisation
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull())
plt.show()

# %%
#Removing irrelevant features6
df.drop(["Id"],axis=1,inplace=True)

# %%
#making seperate lists of categorical and continuos varioables
categorical=[x for x in df.columns if df[x].dtype==object]
cont=[x for x in df.columns if x not in categorical]

# %%
print(len(categorical))
print(len(cont))
# Out:
# 43
# 37

# %%
for i in categorical:
    if df[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df[i].isnull().sum() * 100/len(df[i]),2)))
# Out:
# Alley: 93.41% missing values
# MasVnrType: 0.6% missing values
# BsmtQual: 2.57% missing values
# BsmtCond: 2.57% missing values
# BsmtExposure: 2.65% missing values
# BsmtFinType1: 2.57% missing values
# BsmtFinType2: 2.65% missing values
# FireplaceQu: 47.17% missing values
# GarageType: 5.48% missing values
# GarageFinish: 5.48% missing values
# GarageQual: 5.48% missing values
# GarageCond: 5.48% missing values
# PoolQC: 99.4% missing values
# Fence: 79.71% missing values
# MiscFeature: 96.23% missing values

# %%
#Removing irrelevant features6
df.drop(["PoolQC"],axis=1,inplace=True)

# %% [raw]
# obj_col=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes=='O']
#
# for i in obj_col:
#     print("{}: {}% missing values".format(i, round(df[i].isnull().sum() * 100/len(df[i]),2)))

# %% [raw]
# percent_missing = df['Alley'].isnull().sum() * 100 / len(df['Alley'])
# percent_missing

# %% [raw]
# # For Alley, NA means No_alley_access. Let's replace NAs with 'No_alley_access'
# df['Alley'].fillna('No_alley_access',inplace=True)
# print(df['Alley'].value_counts())

# %% [raw]
# percent_missing = df['Alley'].isnull().sum() * 100 / len(df['Alley'])
# percent_missing

# %% [markdown]
# ###### As per data description ,NA has different meaning for different features.So,lets 1st replace NA with actual words

# %%
# For Alley, NA means No_alley_access. Let's replace NAs with 'No_alley_access'
df['Alley'].fillna('No_alley_access',inplace=True)
print(df['Alley'].value_counts())
# Out:
# No_alley_access    1091
# Grvl                 41
# Pave                 36
# Name: Alley, dtype: int64

# %%
basement=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']
#NA means No_Basement for all i in basement. Let's replace NAs with 'No_Basement'
for i in basement:
    df[i].fillna('No_Basement',inplace=True)
    print(df[i].value_counts())
    
    

# As per given definition, NA means None. Let's replace NAs with 'None'
df['MiscFeature'].fillna('None',inplace=True)
print(df['MiscFeature'].value_counts())

# As per given definition, NA means No_Fence. Let's replace NAs with 'No_Fence'
df['Fence'].fillna('No_Fence',inplace=True)
print(df['Fence'].value_counts())

#NA means No_Fireplace. Let's replace NAs with 'No_Fireplace'
df['FireplaceQu'].fillna('No_Fireplace',inplace=True)
print(df['FireplaceQu'].value_counts())

garage=['GarageType','GarageFinish','GarageQual','GarageCond']
# NA means No_Garage for all i in garage
for i in garage:
    df[i].fillna('No_Garage',inplace=True)
    print(df[i].value_counts())
# Out:
# TA             517
# Gd             498
# Ex              94
# No_Basement     30
# Fa              29
# Name: BsmtQual, dtype: int64
# TA             1041
# Gd               56
# Fa               39
# No_Basement      30
# Po                2
# Name: BsmtCond, dtype: int64
# No             756
# Av             180
# Gd             108
# Mn              93
# No_Basement     31
# Name: BsmtExposure, dtype: int64
# Unf            345
# GLQ            330
# ALQ            174
# BLQ            121
# Rec            109
# LwQ             59
# No_Basement     30
# Name: BsmtFinType1, dtype: int64
# Unf            1002
# Rec              43
# LwQ              40
# No_Basement      31
# BLQ              24
# ALQ              16
# GLQ              12
# Name: BsmtFinType2, dtype: int64
# None    1124
# Shed      40
# Gar2       2
# Othr       1
# TenC       1
# Name: MiscFeature, dtype: int64
# No_Fence    931
# MnPrv       129
# GdPrv        51
# GdWo         47
# MnWw         10
# Name: Fence, dtype: int64
# No_Fireplace    551
# Gd              301
# TA              252
# Fa               25
# Ex               21
# Po               18
# Name: FireplaceQu, dtype: int64
# Attchd       691
# Detchd       314
# BuiltIn       70
# No_Garage     64
# Basment       16
# CarPort        8
# 2Types         5
# Name: GarageType, dtype: int64
# Unf          487
# RFn          339
# Fin          278
# No_Garage     64
# Name: GarageFinish, dtype: int64
# TA           1050
# No_Garage      64
# Fa             39
# Gd             11
# Ex              2
# Po              2
# Name: GarageQual, dtype: int64
# TA           1061
# No_Garage      64
# Fa             28
# Gd              8
# Po              6
# Ex              1
# Name: GarageCond, dtype: int64

# %%
#making seperate lists of categorical and continuos varioables
categorical=[x for x in df.columns if df[x].dtype==object]
cont=[x for x in df.columns if x not in categorical]

# %%
#Again checking for missing value in,object dtype column
for i in categorical:
    if df[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df[i].isnull().sum() * 100/len(df[i]),2)))
# Out:
# MasVnrType: 0.6% missing values

# %% [markdown]
# After replacing all  categorical missing values with respective words,we notice that only 1 column is left with null values,which is  'MasVnrType'

# %%
df['MasVnrType'].value_counts()
# Out:
# None       696
# BrkFace    354
# Stone       98
# BrkCmn      13
# Name: MasVnrType, dtype: int64

# %%
df['MasVnrType']=df['MasVnrType'].fillna(df['MasVnrType'].mode()[0])

# %%
for i in cont:
    if df[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df[i].isnull().sum() * 100/len(df[i]),2)))
# Out:
# LotFrontage: 18.32% missing values
# MasVnrArea: 0.6% missing values
# GarageYrBlt: 5.48% missing values

# %%
#filling missing data with imputation for numerical data
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values  = np.nan, strategy = 'mean')
for i in cont:
    df[i]=imp.fit_transform(df[i].values.reshape(-1,1))

# %%
#visualisation
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # EDA

# %% [markdown]
# ### Statistical Summary

# %% [markdown]
# Now lets understand our data statistically

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1168.0      56.767979     41.940650     20.0      20.00
# LotFrontage    1168.0      70.988470     22.437056     21.0      60.00
# LotArea        1168.0   10484.749144   8957.442311   1300.0    7621.50
# OverallQual    1168.0       6.104452      1.390153      1.0       5.00
# OverallCond    1168.0       5.595890      1.124343      1.0       5.00
# YearBuilt      1168.0    1970.930651     30.145255   1875.0    1954.00
# YearRemodAdd   1168.0    1984.758562     20.785185   1950.0    1966.00
# MasVnrArea     1168.0     102.310078    182.047152      0.0       0.00
# BsmtFinSF1     1168.0     444.726027    462.664785      0.0       0.00
# BsmtFinSF2     1168.0      46.647260    163.520016      0.0       0.00
# BsmtUnfSF      1168.0     569.721747    449.375525      0.0     216.00
# TotalBsmtSF    1168.0    1061.095034    442.272249      0.0     799.00
# 1stFlrSF       1168.0    1169.860445    391.161983    334.0     892.00
# 2ndFlrSF       1168.0     348.826199    439.696370      0.0       0.00
# LowQualFinSF   1168.0       6.380137     50.892844      0.0       0.00
# GrLivArea      1168.0    1525.066781    528.042957    334.0    1143.25
# BsmtFullBath   1168.0       0.425514      0.521615      0.0       0.00
# BsmtHalfBath   1168.0       0.055651      0.236699      0.0       0.00
# FullBath       1168.0       1.562500      0.551882      0.0       1.00
# HalfBath       1168.0       0.388699      0.504929      0.0       0.00
# BedroomAbvGr   1168.0       2.884418      0.817229      0.0       2.00
# KitchenAbvGr   1168.0       1.045377      0.216292      0.0       1.00
# TotRmsAbvGrd   1168.0       6.542808      1.598484      2.0       5.00
# Fireplaces     1168.0       0.617295      0.650575      0.0       0.00
# GarageYrBlt    1168.0    1978.193841     24.198559   1900.0    1962.00
# GarageCars     1168.0       1.776541      0.745554      0.0       1.00
# GarageArea     1168.0     476.860445    214.466769      0.0     338.00
# WoodDeckSF     1168.0      96.206336    126.158988      0.0       0.00
# OpenPorchSF    1168.0      46.559932     66.381023      0.0       0.00
# EnclosedPorch  1168.0      23.015411     63.191089      0.0       0.00
# 3SsnPorch      1168.0       3.639555     29.088867      0.0       0.00
# ScreenPorch    1168.0      15.051370     55.080816      0.0       0.00
# PoolArea       1168.0       3.448630     44.896939      0.0       0.00
# MiscVal        1168.0      47.315068    543.264432      0.0       0.00
# MoSold         1168.0       6.344178      2.686352      1.0       5.00
# YrSold         1168.0    2007.804795      1.329738   2006.0    2007.00
# SalePrice      1168.0  181477.005993  79105.586863  34900.0  130375.00
#
#                          50%        75%       max
# MSSubClass         50.000000      70.00     190.0
# LotFrontage        70.988470      79.25     313.0
# LotArea          9522.500000   11515.50  164660.0
# OverallQual         6.000000       7.00      10.0
# OverallCond         5.000000       6.00       9.0
# YearBuilt        1972.000000    2000.00    2010.0
# YearRemodAdd     1993.000000    2004.00    2010.0
# MasVnrArea          0.000000     160.00    1600.0
# BsmtFinSF1        385.500000     714.50    5644.0
# BsmtFinSF2          0.000000       0.00    1474.0
# BsmtUnfSF         474.000000     816.00    2336.0
# TotalBsmtSF      1005.500000    1291.50    6110.0
# 1stFlrSF         1096.500000    1392.00    4692.0
# 2ndFlrSF            0.000000     729.00    2065.0
# LowQualFinSF        0.000000       0.00     572.0
# GrLivArea        1468.500000    1795.00    5642.0
# BsmtFullBath        0.000000       1.00       3.0
# BsmtHalfBath        0.000000       0.00       2.0
# FullBath            2.000000       2.00       3.0
# HalfBath            0.000000       1.00       2.0
# BedroomAbvGr        3.000000       3.00       8.0
# KitchenAbvGr        1.000000       1.00       3.0
# TotRmsAbvGrd        6.000000       7.00      14.0
# Fireplaces          1.000000       1.00       3.0
# GarageYrBlt      1978.193841    2001.00    2010.0
# GarageCars          2.000000       2.00       4.0
# GarageArea        480.000000     576.00    1418.0
# WoodDeckSF          0.000000     171.00     857.0
# OpenPorchSF        24.000000      70.00     547.0
# EnclosedPorch       0.000000       0.00     552.0
# 3SsnPorch           0.000000       0.00     508.0
# ScreenPorch         0.000000       0.00     480.0
# PoolArea            0.000000       0.00     738.0
# MiscVal             0.000000       0.00   15500.0
# MoSold              6.000000       8.00      12.0
# YrSold           2008.000000    2009.00    2010.0
# SalePrice      163995.000000  215000.00  755000.0

# %% [markdown]
# Observation:

# %% [markdown]
# 1.Std is greater than mean for some features such as LowQualFinSF,PoolArea etc which means data is widely spread & indicate the presence of skewness.

# %% [markdown]
# 2.There is large difference between maxm value and 75% ,which means that outliers are present .

# %% [markdown]
# 3.MasVnrArea,BsmtFinSF1,BsmtFinSF2,2ndFlrSF,LowQualFinSF,BsmtFullBath,HalfBath,Fireplaces,WoodDeckSF,OpenPorchSF,EnclosedPorch,3SsnPorch,ScreenPorch,PoolArea,MiscVal have outliers

# %%
# Describing object types
df.describe(include='object').T
# Out:
#               count unique              top  freq
# MSZoning       1168      5               RL   928
# Street         1168      2             Pave  1164
# Alley          1168      3  No_alley_access  1091
# LotShape       1168      4              Reg   740
# LandContour    1168      4              Lvl  1046
# Utilities      1168      1           AllPub  1168
# LotConfig      1168      5           Inside   842
# LandSlope      1168      3              Gtl  1105
# Neighborhood   1168     25            NAmes   182
# Condition1     1168      9             Norm  1005
# Condition2     1168      8             Norm  1154
# BldgType       1168      5             1Fam   981
# HouseStyle     1168      8           1Story   578
# RoofStyle      1168      6            Gable   915
# RoofMatl       1168      8          CompShg  1144
# Exterior1st    1168     14          VinylSd   396
# Exterior2nd    1168     15          VinylSd   387
# MasVnrType     1168      4             None   703
# ExterQual      1168      4               TA   717
# ExterCond      1168      5               TA  1022
# Foundation     1168      6           CBlock   516
# BsmtQual       1168      5               TA   517
# BsmtCond       1168      5               TA  1041
# BsmtExposure   1168      5               No   756
# BsmtFinType1   1168      7              Unf   345
# BsmtFinType2   1168      7              Unf  1002
# Heating        1168      6             GasA  1143
# HeatingQC      1168      5               Ex   585
# CentralAir     1168      2                Y  1090
# Electrical     1168      5            SBrkr  1070
# KitchenQual    1168      4               TA   578
# Functional     1168      7              Typ  1085
# FireplaceQu    1168      6     No_Fireplace   551
# GarageType     1168      7           Attchd   691
# GarageFinish   1168      4              Unf   487
# GarageQual     1168      6               TA  1050
# GarageCond     1168      6               TA  1061
# PavedDrive     1168      3                Y  1071
# Fence          1168      5         No_Fence   931
# MiscFeature    1168      5             None  1124
# SaleType       1168      9               WD   999
# SaleCondition  1168      6           Normal   945

# %% [markdown]
# We observe that Utilities seems to have only one unique value = 'Allpub'.Therefore we can drop it.

# %%
#Removing irrelevant features6
df.drop(["Utilities"],axis=1,inplace=True)

# %% [markdown]
# # Check Correlation

# %%
df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.336681 -0.124151     0.070462    -0.056978
# LotFrontage     -0.336681     1.000000  0.299452     0.229218    -0.047573
# LotArea         -0.124151     0.299452  1.000000     0.107188     0.017513
# OverallQual      0.070462     0.229218  0.107188     1.000000    -0.083167
# OverallCond     -0.056978    -0.047573  0.017513    -0.083167     1.000000
# YearBuilt        0.023988     0.112655  0.005506     0.575800    -0.377731
# YearRemodAdd     0.056618     0.088799  0.027228     0.555945     0.080669
# MasVnrArea       0.027813     0.188758  0.121086     0.407230    -0.137475
# BsmtFinSF1      -0.052236     0.228996  0.221851     0.219643    -0.028810
# BsmtFinSF2      -0.062403     0.002159  0.056656    -0.040893     0.044336
# BsmtUnfSF       -0.134170     0.113924  0.006600     0.308676    -0.146384
# TotalBsmtSF     -0.214042     0.356107  0.259733     0.528285    -0.162481
# 1stFlrSF        -0.227927     0.403436  0.312843     0.458758    -0.134420
# 2ndFlrSF         0.300366     0.089675  0.059803     0.316624     0.036668
# LowQualFinSF     0.053737     0.007506 -0.001915    -0.039295     0.041877
# GrLivArea        0.086448     0.374251  0.281360     0.599700    -0.065006
# BsmtFullBath     0.004556     0.094046  0.142387     0.101732    -0.039680
# BsmtHalfBath     0.008207     0.001389  0.059282    -0.030702     0.091016
# FullBath         0.140807     0.171773  0.123197     0.548824    -0.171931
# HalfBath         0.168423     0.047816  0.007271     0.296134    -0.052125
# BedroomAbvGr    -0.013283     0.237199  0.117351     0.099639     0.028393
# KitchenAbvGr     0.283506    -0.002729 -0.013075    -0.178220    -0.076047
# TotRmsAbvGrd     0.051179     0.318771  0.184546     0.432579    -0.039952
# Fireplaces      -0.035792     0.230610  0.285983     0.390067    -0.013632
# GarageYrBlt      0.073130     0.055992 -0.034765     0.511482    -0.301881
# GarageCars      -0.027639     0.260252  0.158313     0.596322    -0.161996
# GarageArea      -0.092408     0.322644  0.195162     0.566782    -0.126021
# WoodDeckSF      -0.022609     0.088334  0.216720     0.227137     0.012290
# OpenPorchSF      0.017468     0.151328  0.093080     0.341030    -0.024899
# EnclosedPorch   -0.004252     0.020902 -0.007446    -0.098374     0.056074
# 3SsnPorch       -0.043210     0.051084  0.025794     0.045919     0.040476
# ScreenPorch     -0.013291     0.030405  0.025256     0.059387     0.069463
# PoolArea         0.009583     0.196001  0.097107     0.072247    -0.003603
# MiscVal         -0.023503    -0.001329  0.051679    -0.025786     0.075178
# MoSold          -0.016015     0.022517  0.015141     0.090638     0.005519
# YrSold          -0.038595    -0.003885 -0.035399    -0.048759     0.055517
# SalePrice       -0.060775     0.323779  0.249499     0.789185    -0.065642
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.023988      0.056618    0.027813   -0.052236   -0.062403
# LotFrontage     0.112655      0.088799    0.188758    0.228996    0.002159
# LotArea         0.005506      0.027228    0.121086    0.221851    0.056656
# OverallQual     0.575800      0.555945    0.407230    0.219643   -0.040893
# OverallCond    -0.377731      0.080669   -0.137475   -0.028810    0.044336
# YearBuilt       1.000000      0.592829    0.321905    0.227933   -0.027682
# YearRemodAdd    0.592829      1.000000    0.181385    0.114430   -0.044694
# MasVnrArea      0.321905      0.181385    1.000000    0.265735   -0.065707
# BsmtFinSF1      0.227933      0.114430    0.265735    1.000000   -0.052145
# BsmtFinSF2     -0.027682     -0.044694   -0.065707   -0.052145    1.000000
# BsmtUnfSF       0.155559      0.174732    0.109562   -0.499861   -0.213580
# TotalBsmtSF     0.386265      0.280720    0.365016    0.518940    0.098167
# 1stFlrSF        0.279450      0.233384    0.337143    0.445876    0.093442
# 2ndFlrSF        0.011834      0.155102    0.172741   -0.127656   -0.092049
# LowQualFinSF   -0.189044     -0.072526   -0.070515   -0.070932   -0.000577
# GrLivArea       0.198644      0.295048    0.386791    0.217160   -0.007484
# BsmtFullBath    0.164983      0.104643    0.086444    0.645126    0.163518
# BsmtHalfBath   -0.028161     -0.011375    0.014196    0.063895    0.093692
# FullBath        0.471264      0.444446    0.267278    0.054511   -0.060773
# HalfBath        0.243227      0.194943    0.200190    0.015767   -0.023734
# BedroomAbvGr   -0.080639     -0.035847    0.091312   -0.114888   -0.005788
# KitchenAbvGr   -0.167869     -0.139943   -0.037956   -0.065450   -0.034411
# TotRmsAbvGrd    0.095476      0.206923    0.278661    0.043499   -0.033702
# Fireplaces      0.134313      0.118378    0.242510    0.257482    0.047945
# GarageYrBlt     0.783710      0.615011    0.251293    0.132753   -0.071293
# GarageCars      0.525346      0.428325    0.342077    0.197529   -0.020806
# GarageArea      0.473216      0.387744    0.365280    0.286290   -0.002051
# WoodDeckSF      0.204830      0.197410    0.151579    0.192939    0.094690
# OpenPorchSF     0.191069      0.238755    0.130885    0.108802   -0.014103
# EnclosedPorch  -0.373544     -0.193574   -0.101941   -0.082351    0.032081
# 3SsnPorch       0.037079      0.064763    0.018720    0.025485   -0.031263
# ScreenPorch    -0.058760     -0.046220    0.046498    0.033490    0.076561
# PoolArea        0.006408      0.006874    0.013590    0.154769    0.045990
# MiscVal        -0.030008     -0.001199   -0.027582    0.008314    0.007915
# MoSold          0.031754      0.024663    0.013363    0.007482   -0.014605
# YrSold         -0.013976      0.033265   -0.013462    0.005614    0.038438
# SalePrice       0.514408      0.507831    0.463626    0.362874   -0.010151
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass     ...   -0.022609     0.017468      -0.004252  -0.043210
# LotFrontage    ...    0.088334     0.151328       0.020902   0.051084
# LotArea        ...    0.216720     0.093080      -0.007446   0.025794
# OverallQual    ...    0.227137     0.341030      -0.098374   0.045919
# OverallCond    ...    0.012290    -0.024899       0.056074   0.040476
# YearBuilt      ...    0.204830     0.191069      -0.373544   0.037079
# YearRemodAdd   ...    0.197410     0.238755      -0.193574   0.064763
# MasVnrArea     ...    0.151579     0.130885      -0.101941   0.018720
# BsmtFinSF1     ...    0.192939     0.108802      -0.082351   0.025485
# BsmtFinSF2     ...    0.094690    -0.014103       0.032081  -0.031263
# BsmtUnfSF      ...   -0.001966     0.138456      -0.013251   0.025779
# TotalBsmtSF    ...    0.234848     0.249284      -0.087751   0.041295
# 1stFlrSF       ...    0.235467     0.211107      -0.047798   0.068344
# 2ndFlrSF       ...    0.085662     0.251556       0.065049  -0.026226
# LowQualFinSF   ...   -0.033553     0.025591       0.073690  -0.004030
# GrLivArea      ...    0.242525     0.368318       0.025861   0.028401
# BsmtFullBath   ...    0.161772     0.060848      -0.038337  -0.000783
# BsmtHalfBath   ...    0.051038    -0.050523       0.000917   0.050830
# FullBath       ...    0.176961     0.278700      -0.094774   0.045254
# HalfBath       ...    0.101660     0.226403      -0.089001  -0.010114
# BedroomAbvGr   ...    0.037998     0.099160       0.062807  -0.013974
# KitchenAbvGr   ...   -0.085037    -0.071659       0.030293  -0.026272
# TotRmsAbvGrd   ...    0.153871     0.264800       0.018640  -0.005187
# Fireplaces     ...    0.177070     0.173684      -0.023222   0.014982
# GarageYrBlt    ...    0.216256     0.224879      -0.267555   0.032561
# GarageCars     ...    0.213252     0.219427      -0.130974   0.036901
# GarageArea     ...    0.215972     0.254685      -0.099955   0.035741
# WoodDeckSF     ...    1.000000     0.056290      -0.125435  -0.029961
# OpenPorchSF    ...    0.056290     1.000000      -0.087114   0.003635
# EnclosedPorch  ...   -0.125435    -0.087114       1.000000  -0.040127
# 3SsnPorch      ...   -0.029961     0.003635      -0.040127   1.000000
# ScreenPorch    ...   -0.079504     0.066200      -0.082195  -0.034219
# PoolArea       ...    0.080366     0.067968       0.057362  -0.009619
# MiscVal        ...   -0.006860    -0.018066       0.021375  -0.010906
# MoSold         ...    0.009254     0.068807      -0.036523   0.020406
# YrSold         ...    0.030975    -0.065735      -0.005767   0.014440
# SalePrice      ...    0.315444     0.339500      -0.115004   0.060119
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass       -0.013291  0.009583 -0.023503 -0.016015 -0.038595  -0.060775
# LotFrontage       0.030405  0.196001 -0.001329  0.022517 -0.003885   0.323779
# LotArea           0.025256  0.097107  0.051679  0.015141 -0.035399   0.249499
# OverallQual       0.059387  0.072247 -0.025786  0.090638 -0.048759   0.789185
# OverallCond       0.069463 -0.003603  0.075178  0.005519  0.055517  -0.065642
# YearBuilt        -0.058760  0.006408 -0.030008  0.031754 -0.013976   0.514408
# YearRemodAdd     -0.046220  0.006874 -0.001199  0.024663  0.033265   0.507831
# MasVnrArea        0.046498  0.013590 -0.027582  0.013363 -0.013462   0.463626
# BsmtFinSF1        0.033490  0.154769  0.008314  0.007482  0.005614   0.362874
# BsmtFinSF2        0.076561  0.045990  0.007915 -0.014605  0.038438  -0.010151
# BsmtUnfSF         0.001076 -0.039029 -0.017266  0.030011 -0.049734   0.215724
# TotalBsmtSF       0.064434  0.139252 -0.005920  0.032920 -0.030448   0.595042
# 1stFlrSF          0.070193  0.144006 -0.010792  0.045991 -0.028604   0.587642
# 2ndFlrSF          0.047862  0.090189  0.015327  0.040987 -0.038241   0.330386
# LowQualFinSF      0.037403  0.065630 -0.003564 -0.029194 -0.034952  -0.032381
# GrLivArea         0.095457  0.188102  0.004425  0.065385 -0.056401   0.707300
# BsmtFullBath      0.013853  0.075230 -0.024692 -0.012877  0.060557   0.212924
# BsmtHalfBath      0.008851  0.023210 -0.007833  0.039928 -0.052576  -0.011109
# FullBath         -0.004024  0.055757 -0.013450  0.066975 -0.037073   0.554988
# HalfBath          0.065093  0.024052  0.005151 -0.001426 -0.015796   0.295592
# BedroomAbvGr      0.051035  0.077270  0.015004  0.064584 -0.036551   0.158281
# KitchenAbvGr     -0.050257 -0.016128  0.045887  0.023240 -0.007908  -0.132108
# TotRmsAbvGrd      0.058885  0.094082  0.030337  0.058427 -0.060971   0.528363
# Fireplaces        0.189293  0.104895  0.010342  0.065136 -0.025018   0.459611
# GarageYrBlt      -0.085984 -0.015092 -0.035198  0.003303 -0.011098   0.458007
# GarageCars        0.038549  0.022504 -0.035777  0.080790 -0.057866   0.628329
# GarageArea        0.033950  0.066697 -0.018672  0.057009 -0.037036   0.619000
# WoodDeckSF       -0.079504  0.080366 -0.006860  0.009254  0.030975   0.315444
# OpenPorchSF       0.066200  0.067968 -0.018066  0.068807 -0.065735   0.339500
# EnclosedPorch    -0.082195  0.057362  0.021375 -0.036523 -0.005767  -0.115004
# 3SsnPorch        -0.034219 -0.009619 -0.010906  0.020406  0.014440   0.060119
# ScreenPorch       1.000000  0.058121  0.040486  0.033064  0.017312   0.100284
# PoolArea          0.058121  1.000000  0.029771 -0.038624 -0.066063   0.103280
# MiscVal           0.040486  0.029771  1.000000 -0.008773 -0.008439  -0.013071
# MoSold            0.033064 -0.038624 -0.008773  1.000000 -0.144536   0.072764
# YrSold            0.017312 -0.066063 -0.008439 -0.144536  1.000000  -0.045508
# SalePrice         0.100284  0.103280 -0.013071  0.072764 -0.045508   1.000000
#
# [37 rows x 37 columns]

# %%
plt.figure(figsize=(40,22))
sns.heatmap(df.corr(),fmt='.0%',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Correlation with target column

# %%
plt.figure(figsize=(16,6))
df.drop('SalePrice',axis=1).corrwith(df['SalePrice']).plot(kind='bar',grid=True)
plt.xticks(rotation=90)
plt.title('correlation with target variable')
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %% [markdown]
# Observation

# %% [markdown]
# 1. 'MSSubClass' ,'OverallCond' ,'OverallCond' ,'LowQualFinSF'  ,'BsmtHalfBath' ,'KitchenAbvGr' ,'YrSold', 'EnclosedPorch', 'MiscVal' are negatively correlated with the target column,rest all are positively correlated

# %% [markdown]
# 2. 'OverallQual' & 'GrLivArea' are highly positively correlated with target column

# %% [markdown]
# 3. 'MSSubClass' ,'OverallCond' ,'OverallCond' ,'LowQualFinSF'  ,'BsmtHalfBath'  ,'YrSold', 'MiscVal', 'MoSold', '3SsnPorch' are least correlated with the target column

# %%
#dropping least correlated column
df.drop(['MSSubClass' ,'OverallCond' ,'OverallCond' ,'LowQualFinSF' ,'BsmtHalfBath' ,'YrSold', 'MiscVal', 'MoSold', '3SsnPorch'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1168, 70)

# %% [markdown]
# # CHECKING MULTICOLINEATY

# %% [raw]
# ## checking variables which have correlation coefficient more than 0.7 to check multicollinearilty issue
# plt.figure(figsize=(15,10))
# sb.heatmap(df_corr[df_corr>0.7],annot=True,cmap='Greens')

# %% [raw]
# Some attributes are found having multicollinearity issue

# %% [raw]
# ## removing columns having multicollinearity , so that multicollinearity could not affect predictions
# Data_file.drop(['GarageCars','1stFlrSF','GarageYrBlt','TotRmsAbvGrd'],axis=1,inplace=True)

# %% [raw]
# ## Again checking for confirmation
# df_corr=Data_file.corr()
# plt.figure(figsize=(15,10))
# sb.heatmap(df_corr[df_corr>0.7],annot=True,cmap='Greens')

# %% [raw]
# Multicollinearity removed from dataset (the remaing two columns are left because they are directly related to target variable)

# %% [raw]
# plt.figure(figsize=(15,10))
# sb.heatmap(Data_file.corr(),cmap='Greens',square=True)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Univariate analysis

# %%
#checking the mean fees
fees=df['SalePrice'].hist()
mean_val=np.mean(df['SalePrice'])
plt.axvline(mean_val,linewidth=4,color='red',label='mean SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# From above,we find that mean sale price is around 190000

# %%
#creating new categorical and cont variable list and label encoding the categorical columns
from sklearn.preprocessing import LabelEncoder
categorical=[x for x in df.columns if df[x].dtype==object]
cont=[x for x in df.columns if x not in categorical]

# %%
#getting distribution o data in continuous columns
for i in cont:
    plt.figure(figsize=(10,6))
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# ### observation from above distribution plot

# %% [markdown]
# 1. LotFrontage,LotArea is almost normally distributed

# %% [markdown]
# 2. MasVnrArea,BsmtFinSF1,BsmtFinSF2,BsmtUnfSF,TotalBsmtSF,LowQualFinSF,GrLivArea,WoodDeckSF,OpenPorchSF,EnclosedPorch,saleprice is right skewed

# %% [markdown]
# 3. LotArea,MiscVal,PoolArea,3SsnPorch is leptokurtic

# %% [markdown]
# 4.

# %% [markdown]
# 5.

# %% [markdown]
# 6.

# %%
#visualizing each categorical column wrt count of each value
for i in categorical:
    plt.figure(figsize=(15,6))
    sns.countplot(df[i])
    plt.show()
#checking percentage of data classification in each string attribute
    print(round(df[i].value_counts()/1168*100),2)
# Out:
# RL         79.0
# RM         14.0
# FV          4.0
# RH          1.0
# C (all)     1.0
# Name: MSZoning, dtype: float64 2
# Pave    100.0
# Grvl      0.0
# Name: Street, dtype: float64 2
# No_alley_access    93.0
# Grvl                4.0
# Pave                3.0
# Name: Alley, dtype: float64 2
# Reg    63.0
# IR1    33.0
# IR2     3.0
# IR3     1.0
# Name: LotShape, dtype: float64 2
# Lvl    90.0
# Bnk     4.0
# HLS     4.0
# Low     3.0
# Name: LandContour, dtype: float64 2
# Inside     72.0
# Corner     19.0
# CulDSac     6.0
# FR2         3.0
# FR3         0.0
# Name: LotConfig, dtype: float64 2
# Gtl    95.0
# Mod     4.0
# Sev     1.0
# Name: LandSlope, dtype: float64 2
# NAmes      16.0
# CollgCr    10.0
# OldTown     7.0
# Edwards     7.0
# Somerst     6.0
# Gilbert     5.0
# NridgHt     5.0
# Sawyer      5.0
# NWAmes      5.0
# SawyerW     4.0
# BrkSide     4.0
# Crawfor     4.0
# NoRidge     3.0
# Mitchel     3.0
# IDOTRR      3.0
# Timber      2.0
# ClearCr     2.0
# SWISU       2.0
# StoneBr     2.0
# Blmngtn     1.0
# BrDale      1.0
# Veenker     1.0
# MeadowV     1.0
# NPkVill     1.0
# Blueste     0.0
# Name: Neighborhood, dtype: float64 2
# Norm      86.0
# Feedr      6.0
# Artery     3.0
# RRAn       2.0
# PosN       1.0
# RRAe       1.0
# PosA       1.0
# RRNn       0.0
# RRNe       0.0
# Name: Condition1, dtype: float64 2
# Norm      99.0
# Feedr      1.0
# PosN       0.0
# Artery     0.0
# PosA       0.0
# RRAn       0.0
# RRAe       0.0
# RRNn       0.0
# Name: Condition2, dtype: float64 2
# 1Fam      84.0
# TwnhsE     8.0
# Duplex     4.0
# Twnhs      2.0
# 2fmCon     2.0
# Name: BldgType, dtype: float64 2
# 1Story    49.0
# 2Story    31.0
# 1.5Fin    10.0
# SLvl       4.0
# SFoyer     3.0
# 1.5Unf     1.0
# 2.5Unf     1.0
# 2.5Fin     1.0
# Name: HouseStyle, dtype: float64 2
# Gable      78.0
# Hip        19.0
# Flat        1.0
# Gambrel     1.0
# Mansard     0.0
# Shed        0.0
# Name: RoofStyle, dtype: float64 2
# CompShg    98.0
# Tar&Grv     1.0
# WdShngl     1.0
# WdShake     0.0
# ClyTile     0.0
# Membran     0.0
# Roll        0.0
# Metal       0.0
# Name: RoofMatl, dtype: float64 2
# VinylSd    34.0
# HdBoard    15.0
# MetalSd    15.0
# Wd Sdng    15.0
# Plywood     8.0
# CemntBd     4.0
# BrkFace     4.0
# Stucco      2.0
# WdShing     2.0
# AsbShng     2.0
# Stone       0.0
# ImStucc     0.0
# BrkComm     0.0
# AsphShn     0.0
# Name: Exterior1st, dtype: float64 2
# VinylSd    33.0
# MetalSd    15.0
# HdBoard    15.0
# Wd Sdng    14.0
# Plywood    10.0
# CmentBd     4.0
# Wd Shng     3.0
# Stucco      2.0
# BrkFace     2.0
# AsbShng     2.0
# ImStucc     1.0
# Brk Cmn     0.0
# Stone       0.0
# AsphShn     0.0
# Other       0.0
# Name: Exterior2nd, dtype: float64 2
# None       60.0
# BrkFace    30.0
# Stone       8.0
# BrkCmn      1.0
# Name: MasVnrType, dtype: float64 2
# TA    61.0
# Gd    34.0
# Ex     4.0
# Fa     1.0
# Name: ExterQual, dtype: float64 2
# TA    88.0
# Gd    10.0
# Fa     2.0
# Ex     0.0
# Po     0.0
# Name: ExterCond, dtype: float64 2
# CBlock    44.0
# PConc     44.0
# BrkTil    10.0
# Slab       2.0
# Stone      0.0
# Wood       0.0
# Name: Foundation, dtype: float64 2
# TA             44.0
# Gd             43.0
# Ex              8.0
# No_Basement     3.0
# Fa              2.0
# Name: BsmtQual, dtype: float64 2
# TA             89.0
# Gd              5.0
# Fa              3.0
# No_Basement     3.0
# Po              0.0
# Name: BsmtCond, dtype: float64 2
# No             65.0
# Av             15.0
# Gd              9.0
# Mn              8.0
# No_Basement     3.0
# Name: BsmtExposure, dtype: float64 2
# Unf            30.0
# GLQ            28.0
# ALQ            15.0
# BLQ            10.0
# Rec             9.0
# LwQ             5.0
# No_Basement     3.0
# Name: BsmtFinType1, dtype: float64 2
# Unf            86.0
# Rec             4.0
# LwQ             3.0
# No_Basement     3.0
# BLQ             2.0
# ALQ             1.0
# GLQ             1.0
# Name: BsmtFinType2, dtype: float64 2
# GasA     98.0
# GasW      1.0
# Grav      0.0
# Wall      0.0
# OthW      0.0
# Floor     0.0
# Name: Heating, dtype: float64 2
# Ex    50.0
# TA    30.0
# Gd    16.0
# Fa     3.0
# Po     0.0
# Name: HeatingQC, dtype: float64 2
# Y    93.0
# N     7.0
# Name: CentralAir, dtype: float64 2
# SBrkr    92.0
# FuseA     6.0
# FuseF     2.0
# FuseP     0.0
# Mix       0.0
# Name: Electrical, dtype: float64 2
# TA    49.0
# Gd    41.0
# Ex     7.0
# Fa     3.0
# Name: KitchenQual, dtype: float64 2
# Typ     93.0
# Min2     3.0
# Min1     2.0
# Mod      1.0
# Maj1     1.0
# Maj2     0.0
# Sev      0.0
# Name: Functional, dtype: float64 2
# No_Fireplace    47.0
# Gd              26.0
# TA              22.0
# Fa               2.0
# Ex               2.0
# Po               2.0
# Name: FireplaceQu, dtype: float64 2
# Attchd       59.0
# Detchd       27.0
# BuiltIn       6.0
# No_Garage     5.0
# Basment       1.0
# CarPort       1.0
# 2Types        0.0
# Name: GarageType, dtype: float64 2
# Unf          42.0
# RFn          29.0
# Fin          24.0
# No_Garage     5.0
# Name: GarageFinish, dtype: float64 2
# TA           90.0
# No_Garage     5.0
# Fa            3.0
# Gd            1.0
# Ex            0.0
# Po            0.0
# Name: GarageQual, dtype: float64 2
# TA           91.0
# No_Garage     5.0
# Fa            2.0
# Gd            1.0
# Po            1.0
# Ex            0.0
# Name: GarageCond, dtype: float64 2
# Y    92.0
# N     6.0
# P     2.0
# Name: PavedDrive, dtype: float64 2
# No_Fence    80.0
# MnPrv       11.0
# GdPrv        4.0
# GdWo         4.0
# MnWw         1.0
# Name: Fence, dtype: float64 2
# None    96.0
# Shed     3.0
# Gar2     0.0
# Othr     0.0
# TenC     0.0
# Name: MiscFeature, dtype: float64 2
# WD       86.0
# New       9.0
# COD       3.0
# ConLD     1.0
# ConLI     0.0
# ConLw     0.0
# Oth       0.0
# CWD       0.0
# Con       0.0
# Name: SaleType, dtype: float64 2
# Normal     81.0
# Partial     9.0
# Abnorml     7.0
# Family      2.0
# Alloca      1.0
# AdjLand     0.0
# Name: SaleCondition, dtype: float64 2

# %% [markdown]
# ### Observation from all the count plot

# %% [markdown]
# 1. looking at countplot of  MSZoning ,which Identifies the general zoning classification of the sale,we find that 79 % of houses were sold in Low density resedential Areas

# %% [markdown]
# 2. For street ,which states:Type of road access to property,we observe that almost 100% of house which were sold
# had access to paved roads so we can consider that no houses were purchased which had gravel road access

# %% [markdown]
# 3. For Alley,93% of the purchased house do not have access to alley.Only 4% have gravel & 3% have paved alley

# %% [markdown]
# 4. LotShape : 63% of the sold property  was of Regular shape followed by slightly irregular type (33%).It means Australian gives priority to regular shaped houses

# %% [markdown]
# 5. LandContour :90% of sold houses were neary flat level

# %% [markdown]
# 6. LotConfig : 72% of purchased houses had Inside lot of the property

# %% [markdown]
# 7. LandSlope :Around 95% of the sold property had gentle slope

# %% [markdown]
# 8. Neighborhood: Physical locations within Ames city limits-:highest 16% of purhcased houses has neighbourhood of NWAmes(Northwest Ames) followed by CollgCr(College Creek) and least houses were purchased in neighbour hood of Bluestem

# %% [markdown]
# 9. Condition1: Proximity to various conditions-:86% of purchased houses had normal proximity to various conditions1 and least 0.00 had RRne,RRNn proximity

# %% [markdown]
# 10. Condition2: Proximity to various conditions (if more than one is present)-:99% of purchased houses had normal proximity to various conditions2

# %% [markdown]
# 11. BldgType: Type of dwelling-:84% purchased houses were single family detached,followed by 8% 2FmCon(Two-family Conversion)

# %% [markdown]
# 12. HouseStyle: Style of dwelling-:49% houses had 1story followed by 2story style (31%)

# %% [markdown]
# 13. RoofStyle: Type of roof-:78% of houses have Gable roof style and 19% have Hip roof style

# %% [markdown]
# 14. RoofMatl: Roof material-:98% houses have  CompShg(Standard (Composite) Shingle) roof material

# %% [markdown]
# 15. Exterior1st: Exterior covering on house-:34% houses have Vinylsiding covering on exteriors 15% have hard board and metal siding

# %% [markdown]
# 16. Exterior2nd: Exterior covering on house (if more than one material)-:33% houses have VinylSd(Vinyl Siding) 15% have hard board and metal siding

# %% [markdown]
# 17. MasVnrType: Masonry veneer type-:60% of houses have no masonry veneer type followed by BrkFace(Brick Face) (30%)

# %% [markdown]
# 18. ExterQual: Evaluates the quality of the material on the exterior-:61% of the sold hoUse have TA(Average/Typical) quality material on exterior followed by Gd(Good) 34%

# %% [markdown]
# 19. ExterCond: Evaluates the present condition of the material on the exterior-:88% houses are currently in TA(average) condition of exterior material

# %% [markdown]
# 20. Foundation: Type of foundation-:44% houses have foundation  CBlock(Cinder Block) & 44% have PConc(Poured Contrete)

# %% [markdown]
# 21. BsmtQual: Evaluates the height of the basement-:44% of houses have TA(typical) (80-89 inches) basement height followed by  Gd(Good) (90-99 inches)

# %% [markdown]
# 22. BsmtCond: Evaluates the general condition of the basement-:89% of houses have TA(Typical - slight dampness allowed) basment

# %% [markdown]
# 23. BsmtExposure: Refers to walkout or garden level walls-:64% of houses have  No(No Exposure) followed by Av(Average Exposure ) 15%

# %% [markdown]
# 24. BsmtFinType1: Rating of basement finished area-:(30%) have Unf(Unfinshed) basement area and 28% comes under GLQ(good living quarters)

# %% [markdown]
# 25. Heating: Type of heating-:98% houses have GasA(Gas forced warm air furnace) heating type

# %% [markdown]
# 26.  HeatingQC: Heating quality and condition-:30% houses have average quality heating

# %% [markdown]
# 27. CentralAir: Central air conditioning-:93% houses are central air

# %% [markdown]
# 28. Electrical: Electrical system-:92% houses have SbrKr(Standard Circuit Breakers & Romex) type of electrical systems

# %% [markdown]
# 29. KitchenQual: Kitchen quality-:49% houses have average (TA) kitchen quality

# %% [markdown]
# 30. Functional: Home functionality (Assume typical unless deductions are warranted)-:92% houses have typical (TA) home functionality

# %% [markdown]
# 31. FireplaceQu: Fireplace quality-:47% of the houses donot have fireplace,25% houses have Gd(Good - Masonry Fireplace in main level) FireplaceQuality

# %% [markdown]
# 32. GarageType: Garage location-:57% houses have Attached garage type,while 29% have Detchd(Detached from home)

# %% [markdown]
# 33. GarageFinish: Interior finish of the garage:42% of houses have unfinished garage while 29% have RFn(Rough Finished)

# %% [markdown]
# 34. GarageQual: Garage quality-:90% of houses have average garage quality

# %% [markdown]
# 35. GarageCond: Garage condition-:91% of houses have TA( average garage condition)

# %% [markdown]
# 36. PavedDrive: Paved driveway-:92% of houses have Y( paved drive) way

# %% [markdown]
# 37. PoolQC: Pool quality-:99% houses donot have pool

# %% [markdown]
# 38. Fence: Fence quality-:89% houses have NA(no fence).

# %% [markdown]
# 39. MiscFeature: Miscellaneous feature-:96% houses have no miscellaneous features

# %% [markdown]
# 40. SaleType: Type of sale-:85% houses have sale type WD(warranty deed -conventional)

# %% [markdown]
# 41. SaleCondition:81% of houses are in normal sale condition

# %%
for feature in cont:
    data=df.copy()
    data[feature].hist(bins=20)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# 1. lotFrontage:Almost all houses have LotFrontage between 20 to 150

# %% [markdown]
# 2. lotArea:Around 580 house have lot Area between (0-10000)sqft.Very few houses have lot area aound 120000sqft & around 160000sqft

# %% [markdown]
# 3. OverallQual: Rates the overall material and finish of the house-:Around 300 houses sold were in average condition.Only 10-15 houses were in excellent condition.

# %% [markdown]
# 4. YearBuilt: Original construction date-:More number of people have brought the houses build after 1990

# %% [markdown]
# 5. MasVnrArea: Masonry veneer area in square feet-:50% of houses have Masonry veneer area as '0-50' and out of rest 50% houses most houses have Masonry veneer area 50-1200

# %% [markdown]
# 6. BsmtFinSF1: Type 1 finished square feet-:MOst houses have Type 1 finished square feet area of basement between 0 and 1500

# %% [markdown]
# 7. BsmtFinSF2: Type 2 finished square feet-:Around 1000 houses have Type 2 finished square feet area of 0

# %% [markdown]
# 8. BsmtUnfSF: Unfinished square feet of basement area-:Around 130 houses have unfinished basesent of area around 100-500 sqft

# %% [markdown]
# 9. 1stFlrSF: First Floor square feet-:Around 280  houses have 1st floor square feet area between 800-1200sqft

# %% [markdown]
# 10. GrLivArea: Above grade (ground) living area square feet-:Most houses have above ground living sq ft area in between 800 to 3000

# %% [markdown]
# 11. BsmtFullBath: Basement full bathrooms-:50% houses have no full bathrooms in basement and in remaining houses most have 1 full bathrooms in basement and very few has 2 full bathrooms

# %% [markdown]
# 12. FullBath: Full bathrooms above grade-:25% houses have 1 full bathrooms above ground and 50% have 2 full bathrooms located above ground and very less have 3

# %% [markdown]
# 13. HalfBath: Half baths above grade-: around 700 houses have no half bathrooms  very few has 1 half bathroom

# %% [markdown]
# 14. Bedroom: Bedrooms above grade (does NOT include basement bedrooms)-:Most houses have 3 bedrooms above ground followed by 2 and 4

# %% [markdown]
# 15. Kitchen: Kitchens above grade-:Maximum houses have 1 Kitchen .very few have  2

# %% [markdown]
# 16. TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)-:Around 300 houses have 6 rooms ,around 200 have 5,&250 have 7.Very few have 12 & 14 rooms

# %% [markdown]
# 17. Fireplaces: Number of fireplaces-:Most houses have 0 fireplaces followed by 1

# %% [markdown]
# 18. GarageCars: Size of garage in car capacity-:Most houses have garage with 2 car capcity

# %% [markdown]
# 19. GarageArea: Size of garage in square feet-:Most houses have Garage area in between 200 to 800

# %% [markdown]
# 20. woodDeckSF: Wood deck area in square feet-:More than 50% of houses have 0 Wood Deck sq ft area and rest have in between 0 to 400

# %% [markdown]
# 21. OpenPorchSF: Open porch area in square feet-:25% of houses have 0 open porch sq ft area and rest have in between 0 to 300

# %% [markdown]
# 22. EnclosedPorch: Enclosed porch area in square feet-:Almost all houses have 0 enclosed porch sq ft area

# %% [markdown]
# 23. ScreenPorch: Screen porch area in square feet-:Almost all houses have 0 screen porch area sq ft

# %% [markdown]
# 24. PoolArea: Pool area in square feet-:Almost all houses have 0 sq ft of pool area

# %% [markdown]
# 25. Sale Price-:Around 500 house  have sale price in between 100000 to 200000.Very few houses have sale price of 600000 & 700000

# %% [markdown]
# ### Bivariate analysis

# %%
#lineplot between saleprice & years of experience
plt.figure(figsize=(8,4))
sns.lineplot(x='YearBuilt',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %% [markdown]
# There seems to be a peak in House Prices that were build between 1885-1900, but then there is  drop in price till1980,after that price increases

# %%
#visualizing each categorical column wrt count of each value
for i in categorical:
    plt.figure(figsize=(10,6))
    sns.barplot(x=df[i],y=df['SalePrice'])
    plt.show()
    print(df.groupby(df[i])['SalePrice'].mean())
# Out:
# MSZoning
# C (all)     75208.888889
# FV         209478.461538
# RH         131558.375000
# RL         191004.181034
# RM         129070.975460
# Name: SalePrice, dtype: float64
# Street
# Grvl    121110.750000
# Pave    181684.450172
# Name: SalePrice, dtype: float64
# Alley
# Grvl               125511.073171
# No_alley_access    184016.191567
# Pave               168264.555556
# Name: SalePrice, dtype: float64
# LotShape
# IR1    206038.464103
# IR2    233827.750000
# IR3    226120.833333
# Reg    165906.660811
# Name: SalePrice, dtype: float64
# LandContour
# Bnk    146163.140000
# HLS    214302.166667
# Low    194393.333333
# Lvl    181476.572658
# Name: SalePrice, dtype: float64
# LotConfig
# Corner     182427.635135
# CulDSac    224594.463768
# FR2        171138.636364
# FR3        221500.000000
# Inside     178003.105701
# Name: SalePrice, dtype: float64
# LandSlope
# Gtl    181203.795475
# Mod    185353.313725
# Sev    190160.833333
# Name: SalePrice, dtype: float64
# Neighborhood
# Blmngtn    195987.000000
# Blueste    137500.000000
# BrDale     104081.818182
# BrkSide    122836.000000
# ClearCr    216120.833333
# CollgCr    199517.508475
# Crawfor    208474.688889
# Edwards    128544.216867
# Gilbert    194790.093750
# IDOTRR     101322.666667
# MeadowV     88444.444444
# Mitchel    154654.411765
# NAmes      146511.225275
# NPkVill    141968.750000
# NWAmes     191643.305085
# NoRidge    341260.228571
# NridgHt    312548.655738
# OldTown    133947.197674
# SWISU      142587.333333
# Sawyer     135029.866667
# SawyerW    186909.647059
# Somerst    222649.588235
# StoneBr    301145.736842
# Timber     240579.291667
# Veenker    246833.333333
# Name: SalePrice, dtype: float64
# Condition1
# Artery    137926.315789
# Feedr     142799.731343
# Norm      184692.003980
# PosA      237833.333333
# PosN      219264.705882
# RRAe      139044.444444
# RRAn      190074.850000
# RRNe      190750.000000
# RRNn      238000.000000
# Name: SalePrice, dtype: float64
# Condition2
# Artery    106500.000000
# Feedr     121166.666667
# Norm      181697.129983
# PosA      325000.000000
# PosN      284875.000000
# RRAe      190000.000000
# RRAn      136905.000000
# RRNn      125000.000000
# Name: SalePrice, dtype: float64
# BldgType
# 1Fam      185602.300714
# 2fmCon    133737.037037
# Duplex    133871.609756
# Twnhs     139437.931034
# TwnhsE    186066.111111
# Name: SalePrice, dtype: float64
# HouseStyle
# 1.5Fin    138546.363636
# 1.5Unf    113216.666667
# 1Story    175940.826990
# 2.5Fin    223285.714286
# 2.5Unf    158690.000000
# 2Story    212193.515235
# SFoyer    137508.000000
# SLvl      170140.851064
# Name: SalePrice, dtype: float64
# RoofStyle
# Flat       204080.833333
# Gable      173251.570492
# Gambrel    145111.111111
# Hip        214493.364444
# Mansard    194795.800000
# Shed       225000.000000
# Name: SalePrice, dtype: float64
# RoofMatl
# ClyTile    160000.000000
# CompShg    180009.329545
# Membran    241500.000000
# Metal      180000.000000
# Roll       137000.000000
# Tar&Grv    195747.000000
# WdShake    254250.000000
# WdShngl    390250.000000
# Name: SalePrice, dtype: float64
# Exterior1st
# AsbShng    107774.263158
# AsphShn    100000.000000
# BrkComm     60000.000000
# BrkFace    198391.463415
# CemntBd    242928.476190
# HdBoard    163432.648045
# ImStucc    262000.000000
# MetalSd    148498.196629
# Plywood    178890.075269
# Stone      258500.000000
# Stucco     160602.272727
# VinylSd    215359.676768
# Wd Sdng    152572.724138
# WdShing    155481.578947
# Name: SalePrice, dtype: float64
# Exterior2nd
# AsbShng    114372.833333
# AsphShn    138000.000000
# Brk Cmn    131300.000000
# BrkFace    194772.500000
# CmentBd    247940.380952
# HdBoard    168398.200000
# ImStucc    273712.500000
# MetalSd    148570.398844
# Other      319000.000000
# Plywood    169979.042373
# Stone      174406.000000
# Stucco     153066.695652
# VinylSd    215607.100775
# Wd Sdng    152218.969697
# Wd Shng    156650.000000
# Name: SalePrice, dtype: float64
# MasVnrType
# BrkCmn     141990.076923
# BrkFace    205275.432203
# None       159079.399716
# Stone      261417.867347
# Name: SalePrice, dtype: float64
# ExterQual
# Ex    357817.651163
# Fa     87435.727273
# Gd    231009.743073
# TA    144918.163180
# Name: SalePrice, dtype: float64
# ExterCond
# Ex    243000.000000
# Fa    105294.769231
# Gd    171391.837607
# Po     76500.000000
# TA    184551.990215
# Name: SalePrice, dtype: float64
# Foundation
# BrkTil    137895.285714
# CBlock    149858.994186
# PConc     225757.504873
# Slab      110846.428571
# Stone     177651.000000
# Wood      164000.000000
# Name: SalePrice, dtype: float64
# BsmtQual
# Ex             331469.978723
# Fa             121349.000000
# Gd             203225.445783
# No_Basement    107897.500000
# TA             140898.736944
# Name: SalePrice, dtype: float64
# BsmtCond
# Fa             121075.102564
# Gd             219908.107143
# No_Basement    107897.500000
# Po              64000.000000
# TA             184018.669549
# Name: SalePrice, dtype: float64
# BsmtExposure
# Av             204174.861111
# Gd             250581.138889
# Mn             194213.838710
# No             167539.144180
# No_Basement    110626.612903
# Name: SalePrice, dtype: float64
# BsmtFinType1
# ALQ            161003.879310
# BLQ            152803.396694
# GLQ            236871.596970
# LwQ            152712.711864
# No_Basement    107897.500000
# Rec            143592.844037
# Unf            172159.521739
# Name: SalePrice, dtype: float64
# BsmtFinType2
# ALQ            194712.500000
# BLQ            154815.958333
# GLQ            194937.500000
# LwQ            168846.250000
# No_Basement    113578.225806
# Rec            164477.325581
# Unf            185077.455090
# Name: SalePrice, dtype: float64
# Heating
# Floor     72500.000000
# GasA     182591.394576
# GasW     167312.785714
# Grav      70080.000000
# OthW     129500.000000
# Wall      92100.000000
# Name: SalePrice, dtype: float64
# HeatingQC
# Ex    215954.223932
# Fa    126556.710526
# Gd    158909.833333
# Po     87000.000000
# TA    142684.883523
# Name: SalePrice, dtype: float64
# CentralAir
# N    108539.576923
# Y    186696.381651
# Name: SalePrice, dtype: float64
# Electrical
# FuseA    121840.986486
# FuseF    109611.285714
# FuseP    109500.000000
# Mix       67000.000000
# SBrkr    187253.339252
# Name: SalePrice, dtype: float64
# KitchenQual
# Ex    327812.329268
# Fa    105028.100000
# Gd    211076.234310
# TA    140206.313149
# Name: SalePrice, dtype: float64
# Functional
# Maj1    151443.090909
# Maj2     86000.000000
# Min1    152630.000000
# Min2    146841.666667
# Mod     145241.666667
# Sev     129000.000000
# Typ     184204.948387
# Name: SalePrice, dtype: float64
# FireplaceQu
# Ex              346091.142857
# Fa              166214.000000
# Gd              221925.581395
# No_Fireplace    142411.822142
# Po              131487.944444
# TA              209946.753968
# Name: SalePrice, dtype: float64
# GarageType
# 2Types       144200.000000
# Attchd       203675.839363
# Basment      160708.937500
# BuiltIn      254970.900000
# CarPort      109957.375000
# Detchd       135873.799363
# No_Garage    102200.000000
# Name: SalePrice, dtype: float64
# GarageFinish
# Fin          241223.809353
# No_Garage    102200.000000
# RFn          201925.554572
# Unf          143555.156057
# Name: SalePrice, dtype: float64
# GarageQual
# Ex           297750.000000
# Fa           129889.000000
# Gd           219822.727273
# No_Garage    102200.000000
# Po           102000.000000
# TA           187753.449524
# Name: SalePrice, dtype: float64
# GarageCond
# Ex           120500.000000
# Fa           115031.821429
# Gd           179921.250000
# No_Garage    102200.000000
# Po           110500.000000
# TA           188483.112158
# Name: SalePrice, dtype: float64
# PavedDrive
# N    116421.472973
# P    133326.086957
# Y    187006.026144
# Name: SalePrice, dtype: float64
# Fence
# GdPrv       181743.529412
# GdWo        134593.255319
# MnPrv       151392.798450
# MnWw        135715.000000
# No_Fence    188489.279270
# Name: SalePrice, dtype: float64
# MiscFeature
# Gar2    170750.000000
# None    182541.548043
# Othr    133000.000000
# Shed    151598.575000
# TenC    250000.000000
# Name: SalePrice, dtype: float64
# SaleType
# COD      146722.368421
# CWD      171166.666667
# Con      269600.000000
# ConLD    146141.000000
# ConLI    200390.000000
# ConLw    143625.000000
# New      271104.500000
# Oth      119850.000000
# WD       173668.456456
# Name: SalePrice, dtype: float64
# SaleCondition
# Abnorml    147567.938272
# AdjLand    104125.000000
# Alloca     167377.416667
# Family     149138.888889
# Normal     175436.408466
# Partial    269585.231481
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Observation

# %% [markdown]
# 1. MSZoning:The avg sale price of the house is maximum in FV(Floating Village Residential) foloowed by  RL(Residential Low Density) zone

# %% [markdown]
# 2. Street:The property  that have access to paved road have much higher average sale price  as compared to that with gravel street

# %% [markdown]
# 3. Alley:houses that do not have access to alley have higher sale price as compared to those with paved or gravel alley

# %% [markdown]
# 4. LotShape:sale price is not much affected by lotshape,however IR2(Moderately Irregular) have a bit higher price compared to other while Reg(Regular) have lowest avg sale price

# %% [markdown]
# 5. LandContour:Flatness of the property-:HLS(Hillside - Significant slope from side to side)  have maximum average sale price & Bnk(Banked - Quick and significant rise from street grade to building) have miimum average sale price

# %% [markdown]
# 6. LandSlope: It doesn't affect the average sale price of house

# %% [markdown]
# 7. Neighborhood:The houses that has a neighbourhood of NoRidge(Northridge) has the maximum sale price followed by that with a neighbourhood of NridgHt(Northridge Heights)

# %% [markdown]
# 8. Condition1:house that is RRAn(Adjacent to North-South Railroad) has hightest avg sale price followed by PosA(Adjacent to postive off-site feature) while houses that is Artery(Adjacent to arterial street) has a minimum average sale price.

# %% [markdown]
# 9. BldgType: Type of dwelling-:TwnhsE(Townhouse End Unit) & 1Fam(Single-family Detached) type house have hightset selling price .

# %% [markdown]
# 10. HouseStyle: Style of dwelling-:The average sale price of 2.5Fin(Two and one-half story) is maximum followed by 2Story(Two story). 1.5Unf(One and one-half story: 2nd level unfinished) have lowest avg selling price

# %% [markdown]
# 11. RoofMatl: Roof material-:House with roof material WdShngl(Wood Shingles) have a very high average selling price,followed by that with roof of WdShake(Wood Shakes),while house with roof material Roll(Roll) have lowest sale price

# %% [markdown]
# 12. Exterior1st: Exterior covering on house-:House with exterior covering of ImStucc(Imitation Stucco) have maximum selling price while that with exterior coverng of BrkComm(Brick Common) have minimum average selling price

# %% [markdown]
# 13. ExterQual: Evaluates the quality of the material on the exterior-:Houses with exterior material of excellent quality have highest saelling price followed by that of gd(good) quality

# %% [markdown]
# 14. KitchenQual: Kitchen quality-:Houses with Ex(Excellent) kitchen quality have higher sale price while that with Fa(Fair) kitchen quality of lower selling price

# %%
# As clear from above a lot of features are not normally distributed. Let's do log transformation
for i in cont:
    plt.scatter(df[i],df['SalePrice'])
    plt.xlabel(i)
    plt.ylabel('SalesPrice')
    plt.title(i)
    plt.show()

# %% [markdown]
# 1. LotFrontage: Linear feet of street connected to property-: Lot frontage doed not impact much on sale price since houses with different sale price are having same Lot frontage area

# %% [markdown]
# 2. LotArea: Lot size in square feet-: LotArea doesn't affect sale price of the houses much, as can be seen different sale price are availble within the Lot area range of 0 to 20000.In fact some houses where Lot Area is very large have moderate sale price

# %% [markdown]
# 3. OverallQual: Rates the overall material and finish of the house-:Overall quality is directly proportional to the sale price of houses

# %% [markdown]
# 4. YearBuilt: & YearRemodAdd: Houses which are build latest have high sale price in comparison to those build in early years.similar is the case with remodelling date

# %% [markdown]
# 5. BsmtFinSF1: Type 1 finished square feet-:Total sq ft of basement area is directly proportional to sale price

# %% [markdown]
# 6. Houses with higher number of full bathrooms seems having high sale price

# %% [markdown]
# 7. Kitchen: Kitchens above grade-:houses with 1 kitchen above ground have high sale price in comparison to those having 2 kitchens

# %% [markdown]
# 8. Fireplaces: Number of fireplaces-:Houses with 1 and 2 fireplaces have higher prices in comparion to houses having 0 or 3 fireplaces

# %% [markdown]
# 9. Wood deck,Enclosed porch,Three season porch, screen porch,pool area,Miscval do not have impact on sale price

# %%
df.shape
# Out:
# (1168, 70)

# %%
#transform non numeric column into numeric one
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype==np.number:
        continue
    df[col]=le.fit_transform(df[col])

# %%
df.skew()
# Out:
# MSZoning         -1.796785
# LotFrontage       2.710383
# LotArea          10.659285
# Street          -17.021969
# Alley            -0.203241
#                    ...
# Fence            -1.955758
# MiscFeature       4.958391
# SaleType         -3.660513
# SaleCondition    -2.671829
# SalePrice         1.953878
# Length: 70, dtype: float64

# %%
#treating skewness via squareroot method and cube root method
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
df.plot(kind='box',subplots=True,layout=(12,8),figsize=(15,10))
# Out:
# MSZoning            AxesSubplot(0.125,0.826831;0.0824468x0.053169)
# LotFrontage      AxesSubplot(0.223936,0.826831;0.0824468x0.053169)
# LotArea          AxesSubplot(0.322872,0.826831;0.0824468x0.053169)
# Street           AxesSubplot(0.421809,0.826831;0.0824468x0.053169)
# Alley            AxesSubplot(0.520745,0.826831;0.0824468x0.053169)
#                                        ...
# Fence            AxesSubplot(0.223936,0.316408;0.0824468x0.053169)
# MiscFeature      AxesSubplot(0.322872,0.316408;0.0824468x0.053169)
# SaleType         AxesSubplot(0.421809,0.316408;0.0824468x0.053169)
# SaleCondition    AxesSubplot(0.520745,0.316408;0.0824468x0.053169)
# SalePrice        AxesSubplot(0.619681,0.316408;0.0824468x0.053169)
# Length: 70, dtype: object

# %%
#removing outliers
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)

df_new=df.loc[(z_score<6).all(axis=1)]
print(df_new.shape)
# Out:
# (1168, 70)
# (1084, 70)

# %% [markdown]
# When we apply z-score of 3 , 57% of the data is lost (due to the wide spread of most of the data). We compromised by enlarging the z-score cut-off to 6 resulting in a loss of few data.

# %% [markdown]
# # Feature Selection

# %%
#spliting the data into input and output variable
x=df_new.drop('SalePrice',axis=1)
x.head()
# Out:
#    MSZoning  LotFrontage     LotArea  Street  Alley  LotShape  LandContour  \
# 0   1.44225     8.425466   70.199715     1.0      1       0.0      1.44225
# 2   1.44225     9.591663   99.599197     1.0      1       0.0      1.44225
# 3   1.44225    10.246951  108.402030     1.0      1       0.0      1.44225
# 4   1.44225     8.425466  128.976742     1.0      1       0.0      1.44225
# 5   1.44225     7.615773  118.549568     1.0      1       0.0      1.44225
#
#    LotConfig  LandSlope  Neighborhood  ...  PavedDrive  WoodDeckSF  \
# 0   1.587401        0.0            13  ...    1.259921    0.000000
# 2   1.000000        0.0            15  ...    1.259921   13.416408
# 3   1.587401        0.0            14  ...    1.259921    0.000000
# 4   1.259921        0.0            14  ...    1.259921   15.491933
# 5   1.587401        0.0             8  ...    1.259921   10.000000
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  PoolArea     Fence  MiscFeature  \
# 0    14.317821            0.0          0.0       0.0  1.587401          1.0
# 2    11.401754            0.0          0.0       0.0  1.587401          1.0
# 3    11.045361            0.0          0.0       0.0  1.259921          1.0
# 4     0.000000            0.0          0.0       0.0  1.587401          1.0
# 5     4.123106            0.0          0.0       0.0  1.587401          1.0
#
#    SaleType  SaleCondition
# 0  2.000000       1.587401
# 2  2.000000       1.587401
# 3  0.000000       1.587401
# 4  2.000000       1.587401
# 5  1.817121       1.709976
#
# [5 rows x 69 columns]

# %%
y=df_new['SalePrice']
y.head()
# Out:
# 0    357.770876
# 2    519.413130
# 3    435.889894
# 4    463.680925
# 5    468.198676
# Name: SalePrice, dtype: float64

# %%
# checking the shape of input & target variable
print(x.shape)
print(y.shape)
# Out:
# (1084, 69)
# (1084,)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(df_new)
x=pd.DataFrame(x,columns=df_new.columns)
x.head()
# Out:
#    MSZoning  LotFrontage   LotArea  Street     Alley  LotShape  LandContour  \
# 0  0.033566     0.106441 -1.234330     0.0  0.021482 -1.410876     0.264179
# 1  0.033566     1.087010  0.132362     0.0  0.021482 -1.410876     0.264179
# 2  0.033566     1.637992  0.541579     0.0  0.021482 -1.410876     0.264179
# 3  0.033566     0.106441  1.498035     0.0  0.021482 -1.410876     0.264179
# 4  0.033566    -0.574369  1.013308     0.0  0.021482 -1.410876     0.264179
#
#    LotConfig  LandSlope  Neighborhood  ...  WoodDeckSF  OpenPorchSF  \
# 0   0.546909  -0.206451      0.129246  ...   -0.920683     1.981368
# 1  -0.414460  -0.206451      0.460849  ...    0.947972     1.381649
# 2   0.546909  -0.206451      0.295047  ...   -0.920683     1.308353
# 3   0.010940  -0.206451      0.295047  ...    1.237054    -0.963241
# 4   0.546909  -0.206451     -0.699762  ...    0.472130    -0.115282
#
#    EnclosedPorch  ScreenPorch  PoolArea     Fence  MiscFeature  SaleType  \
# 0      -0.391045      -0.2886       0.0  0.368025    -0.187495  0.255365
# 1      -0.391045      -0.2886       0.0  0.368025    -0.187495  0.255365
# 2      -0.391045      -0.2886       0.0 -0.619532    -0.187495 -5.229753
# 3      -0.391045      -0.2886       0.0  0.368025    -0.187495  0.255365
# 4      -0.391045      -0.2886       0.0  0.368025    -0.187495 -0.246193
#
#    SaleCondition  SalePrice
# 0       0.243456  -0.739769
# 1       0.243456   1.251579
# 2       0.243456   0.222617
# 3       0.243456   0.564988
# 4       0.554917   0.620644
#
# [5 rows x 70 columns]

# %%
# PCA is required for the analysis to reduce curse of Dimensionality & at the same time minimizing information loss 
from sklearn.decomposition import PCA
for i in range(20,50):
    pca = PCA(n_components=i)
    x_pca=pca.fit_transform(x)
    print(i," variance :{}".format(np.sum(pca.explained_variance_ratio_)))
# Out:
# 20  variance :0.649214150244403
# 21  variance :0.6638322112407415
# 22  variance :0.6790541463352756
# 23  variance :0.693103810585404
# 24  variance :0.7056849432695319
# 25  variance :0.7198445477428911
# 26  variance :0.7323086067957107
# 27  variance :0.7453222396672078
# 28  variance :0.7573671326655002
# 29  variance :0.7695492863746034
# 30  variance :0.7803154448171021
# 31  variance :0.7917896996074363
# 32  variance :0.8024419526468871
# 33  variance :0.8133126067320092
# 34  variance :0.8233084833073229
# 35  variance :0.8331967843414705
# 36  variance :0.8430468485065841
# 37  variance :0.852404856801352
# 38  variance :0.8615939331340806
# 39  variance :0.8705005619129653
# 40  variance :0.8792184734021644
# 41  variance :0.8877952496856375
# 42  variance :0.8957598854676729
# 43  variance :0.9032906674419234
# 44  variance :0.9104232646322031
# 45  variance :0.9171548452069063
# 46  variance :0.9234923760261567
# 47  variance :0.9297691494068326
# 48  variance :0.9357827849878032
# 49  variance :0.941403197508947

# %%
# Selecting 49 features, as it explains 99% of data

# %%
#lets use n=14
pca = PCA(n_components=49)
x=pca.fit_transform(x)

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.20, random_state=42)

# %%
print('x_train_shape:',x_train.shape)
print('x_test_shape:',x_test.shape)
print('y_train_shape:',y_train.shape)
print('y_test_shape:',y_test.shape)
# Out:
# x_train_shape: (867, 49)
# x_test_shape: (217, 49)
# y_train_shape: (867,)
# y_test_shape: (217,)

# %%
#pip install xgboost

# %%
#Importing all the model library

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

#Importing boosting model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb

#import error metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    lg=LinearRegression()
    lg.fit(x_train,y_train)
    lg_pred=lg.predict(x_test)
    r2_scr=r2_score(y_test,lg_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print('max r2 score corresponding to ',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding to  66 is 0.9501222608932011

# %%
#using GridsearchCV to find the best parmeter in  KNeighborsClassifier
parameters={'n_neighbors':range(20,30),'algorithm' : ('auto', 'ball_tree', 'kd_tree', 'brute')}
knn=KNeighborsRegressor()
clf=GridSearchCV(knn,parameters)
clf.fit(x,y)

print(clf.best_params_)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 20}

# %%
#using GridsearchCV to find the best parmeter in  DecisionTreeClassifier

parameters={'criterion':('mse', 'friedman_mse', 'mae'),'splitter' : ("best", "random"),'random_state':range(42,100)}
dtc=DecisionTreeRegressor()
clf=GridSearchCV(dtc,parameters)
clf.fit(x,y)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'random_state': 42, 'splitter': 'best'}

# %%
#gridsearchcv for svc
parameters={'kernel':('linear', 'poly', 'rbf', 'sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x,y)


print(clf.best_params_)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
parameters={'learning_rate':[0.01,0.02,0.03,0.04],'subsample':[0.9,0.5,0.2,0.1],'n_estimators':[100,500,1000],'max_depth':[4,6,8,10]}
gbr=GradientBoostingRegressor()

clf=GridSearchCV(gbr,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000, 'subsample': 0.2}

# %%
parameters={'bootstrap': [True, False],'max_features': ['auto', 'sqrt'],'min_samples_leaf': [1, 2, 4],'min_samples_split': [2, 5, 10],'n_estimators': [10,20,30]}
rfr=RandomForestRegressor()
clf=GridSearchCV(rfr,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'bootstrap': True, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 20}

# %%
parameters={'booster':['gbtree','gblinear'],'base_score':[0.25,0.5,0.75,1]}
XGB = xgb.XGBRegressor()
clf=GridSearchCV(XGB,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'base_score': 1, 'booster': 'gblinear'}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=66)

# %%
#models with is best parameters
lg= LinearRegression()
knn=KNeighborsRegressor(algorithm= 'auto', n_neighbors= 20)
svr=SVR(C= 10, kernel= 'linear')
dtc=DecisionTreeRegressor(criterion= 'mse', random_state= 42, splitter='best')
rfr=RandomForestRegressor(bootstrap= True, max_features= 'auto', min_samples_leaf= 2, min_samples_split= 5, n_estimators= 20)
XGB = xgb.XGBRegressor(base_score= 1, booster= 'gblinear')
gbr=GradientBoostingRegressor(learning_rate=0.01, max_depth= 6, n_estimators= 1000, subsample=0.2)

# %%
#All Algorithm by using for loop

model=[lg,knn,svr,dtc,Lasso(),Ridge(),ElasticNet(),
       rfr,gbr,XGB]

for m in model:
    m.fit(x_train,y_train)
    score=m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('score of ',m,'is',score)
    print('MAE:',mean_absolute_error(y_test,predm))
    print('MSE:',mean_squared_error(y_test,predm))
    print('RMSE:',np.sqrt(mean_squared_error(y_test,predm)))
    print('R2_SCORE:',r2_score(y_test,predm))
    print('*****************************************************************************************')
    print('\n')
# Out:
# score of  LinearRegression() is 0.9095626976782386
# MAE: 13.798416112595607
# MSE: 325.4170105659545
# RMSE: 18.039318461792135
# R2_SCORE: 0.9501222608932011
# *****************************************************************************************
#
#
# score of  KNeighborsRegressor(n_neighbors=20) is 0.8203260775975738
# MAE: 21.527822407677753
# MSE: 844.0598239819616
# RMSE: 29.052707687614276
# R2_SCORE: 0.8706281653258251
# *****************************************************************************************
#
#
# score of  SVR(C=10, kernel='linear') is 0.9046848138969816
# MAE: 13.923563227943449
# MSE: 319.9882990656636
# RMSE: 17.88821676595137
# R2_SCORE: 0.9509543374199526
# *****************************************************************************************
#
#
# score of  DecisionTreeRegressor(random_state=42) is 1.0
# MAE: 29.60596087896563
# MSE: 1526.5701679707197
# RMSE: 39.071347148143225
# R2_SCORE: 0.7660175525740269
# *****************************************************************************************
#
#
# score of  Lasso() is 0.903494297419779
# MAE: 13.853176783263168
# MSE: 326.48245295252485
# RMSE: 18.06882544474114
# R2_SCORE: 0.949958957022582
# *****************************************************************************************
#
#
# score of  Ridge() is 0.9095625675352056
# MAE: 13.79811190790161
# MSE: 325.3755117445287
# RMSE: 18.038168192600065
# R2_SCORE: 0.9501286215545098
# *****************************************************************************************
#
#
# score of  ElasticNet() is 0.896554682077115
# MAE: 14.619122669140216
# MSE: 379.10504913092774
# RMSE: 19.470620152705145
# R2_SCORE: 0.9418933180483194
# *****************************************************************************************
#
#
# score of  RandomForestRegressor(min_samples_leaf=2, min_samples_split=5, n_estimators=20) is 0.9694450964273096
# MAE: 17.4574381115286
# MSE: 546.3863019254105
# RMSE: 23.374907527633354
# R2_SCORE: 0.9162535683934665
# *****************************************************************************************
#
#
# score of  GradientBoostingRegressor(learning_rate=0.01, max_depth=6, n_estimators=1000,
#                           subsample=0.2) is 0.989768323894173
# MAE: 13.424863163991713
# MSE: 344.6890191251181
# RMSE: 18.56580240994496
# R2_SCORE: 0.9471683765424531
# *****************************************************************************************
#
#
# score of  XGBRegressor(base_score=1, booster='gblinear', colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=-1, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.5, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=4, num_parallel_tree=None, random_state=0,
#              reg_alpha=0, reg_lambda=0, scale_pos_weight=1, subsample=None,
#              tree_method=None, validate_parameters=1, verbosity=None) is 0.9095627045913971
# MAE: 13.798415627942477
# MSE: 325.4172301700391
# RMSE: 18.03932454860877
# R2_SCORE: 0.9501222272337583
# *****************************************************************************************

# %%
#cross validate the models
from sklearn.model_selection import cross_val_score
model=[lg,knn,svr,dtc,Lasso(),Ridge(),ElasticNet(),
       rfr,gbr,XGB]
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('score of ',m,'is:')
    print('score:',score)
    print('mean score:',score.mean())
    print('standard deviation:',score.std())
    print('******************************************************')
    print('\n')
# Out:
# score of  LinearRegression() is:
# score: [0.92228374 0.86991717 0.89757893 0.9220412  0.89467343]
# mean score: 0.9012988955117107
# standard deviation: 0.0195609542775072
# ******************************************************
#
#
# score of  KNeighborsRegressor(n_neighbors=20) is:
# score: [0.8384781  0.82081502 0.81587509 0.80788708 0.75895715]
# mean score: 0.8084024890912058
# standard deviation: 0.026681679780990127
# ******************************************************
#
#
# score of  SVR(C=10, kernel='linear') is:
# score: [0.92326698 0.86826123 0.91300252 0.92062729 0.8851281 ]
# mean score: 0.902057224362467
# standard deviation: 0.02164839622641419
# ******************************************************
#
#
# score of  DecisionTreeRegressor(random_state=42) is:
# score: [0.79354424 0.78605607 0.73065456 0.75479748 0.79901885]
# mean score: 0.7728142417452593
# standard deviation: 0.026053035619522706
# ******************************************************
#
#
# score of  Lasso() is:
# score: [0.92587696 0.87098352 0.91220929 0.91555338 0.88850743]
# mean score: 0.9026261160667568
# standard deviation: 0.020000722152666336
# ******************************************************
#
#
# score of  Ridge() is:
# score: [0.9223331  0.86995265 0.89769308 0.92202655 0.89467426]
# mean score: 0.9013359285914465
# standard deviation: 0.019552702798451137
# ******************************************************
#
#
# score of  ElasticNet() is:
# score: [0.92523815 0.86792945 0.90918761 0.90296355 0.88185106]
# mean score: 0.8974339630902977
# standard deviation: 0.020273829380672067
# ******************************************************
#
#
# score of  RandomForestRegressor(min_samples_leaf=2, min_samples_split=5, n_estimators=20) is:
# score: [0.89717119 0.85156259 0.87225277 0.87634841 0.8643915 ]
# mean score: 0.8723452915533564
# standard deviation: 0.015016940445466143
# ******************************************************
#
#
# score of  GradientBoostingRegressor(learning_rate=0.01, max_depth=6, n_estimators=1000,
#                           subsample=0.2) is:
# score: [0.91063682 0.88449972 0.8975203  0.91700629 0.89996865]
# mean score: 0.901926354795601
# standard deviation: 0.011226843625159239
# ******************************************************
#
#
# score of  XGBRegressor(base_score=1, booster='gblinear', colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=-1, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.5, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=4, num_parallel_tree=None, random_state=0,
#              reg_alpha=0, reg_lambda=0, scale_pos_weight=1, subsample=None,
#              tree_method=None, validate_parameters=1, verbosity=None) is:
# score: [0.9222837  0.86991721 0.89757893 0.92204118 0.89467338]
# mean score: 0.90129888065573
# standard deviation: 0.01956093081715962
# ******************************************************

# %%
from sklearn.model_selection import GridSearchCV,KFold,cross_val_score
folds  = KFold(n_splits=10,shuffle=True,random_state=42)

hyper_param = {'alpha':[0.001,0.01,0.1,0.2,0.5,0.9,1.0, 5.0, 10.0,20.0]}

model = Ridge()

model_cv = GridSearchCV(estimator=model,
                        param_grid=hyper_param,
                        scoring='r2',
                        cv=folds,
                        verbose=1,
                        return_train_score=True)

model_cv.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.2, 0.5, 0.9, 1.0, 5.0,
#                                    10.0, 20.0]},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
model_cv.best_params_
# Out:
# {'alpha': 20.0}

# %%
ridge = Ridge(alpha=20)
ridge.fit(x_train,y_train)

y_train_pred = ridge.predict(x_train)
print(r2_score(y_train,y_train_pred))
y_test_pred = ridge.predict(x_test)
print(r2_score(y_test,y_test_pred))
# Out:
# 0.9095144127299039
# 0.9502037931002179

# %%
model_parameter = list(ridge.coef_)
model_parameter.insert(0,ridge.intercept_)
cols = df.columns
cols.insert(0,'constant')
ridge_coef = pd.DataFrame(list(zip(cols,model_parameter)))
ridge_coef.columns = ['Feaure','Coef']
ridge_coef.sort_values(by='Coef',ascending=False).head(10)
# Out:
#           Feaure        Coef
# 0       MSZoning  417.766979
# 1    LotFrontage   22.304992
# 48  TotRmsAbvGrd    6.511798
# 5       LotShape    6.100673
# 9   Neighborhood    4.621905
# 2        LotArea    4.576152
# 32    BsmtFinSF2    4.275417
# 4          Alley    3.400659
# 35       Heating    3.079269
# 21    MasVnrType    2.891952

# %%
# Let's convert all coeff values to absolute to compare positive and negative importance of the featutres
df_feature=ridge_coef
df_feature['Coef_Absolute']=df_feature['Coef'].abs()
df_feature['Colour']=''
for i in range(len(df_feature)):
    if df_feature['Coef'][i] < 0:
        df_feature['Colour'][i]='green'
    else:
        df_feature['Colour'][i]='blue'

# %%
df_top=df_feature.sort_values('Coef_Absolute',ascending=False).head(10)
df_top
# Out:
#           Feaure        Coef  Coef_Absolute Colour
# 0       MSZoning  417.766979     417.766979   blue
# 1    LotFrontage   22.304992      22.304992   blue
# 49    Functional   -7.552401       7.552401  green
# 48  TotRmsAbvGrd    6.511798       6.511798   blue
# 3         Street   -6.304839       6.304839  green
# 5       LotShape    6.100673       6.100673   blue
# 7      LotConfig   -4.881996       4.881996  green
# 9   Neighborhood    4.621905       4.621905   blue
# 20   Exterior2nd   -4.608591       4.608591  green
# 2        LotArea    4.576152       4.576152   blue

# %%
plt.figure(figsize=(20,5))
colors = {'Positive':'blue', 'Negative':'green'}         
labels = list(colors.keys())
plt.bar(df_top['Feaure'], df_top['Coef_Absolute'], color = df_top.Colour, label=labels)
plt.xticks(rotation=45)
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)
plt.title('Effect of Top 10 Features on Sales Price')
# Out:
# Text(0.5, 1.0, 'Effect of Top 10 Features on Sales Price')

# %%
sns.distplot(y_test-y_test_pred)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
# We are getting an almost normal distribution in our predicted values
plt.scatter(y_test,y_test_pred)

# %%
# The model is also almost a straight line

# %%
import joblib
joblib.dump(ridge,'House_Price_Prediction.pkl')
# Out:
# ['House_Price_Prediction.pkl']

# %% [markdown]
# https://github.com/shama1996/housing/blob/main/HOUSING-%20PRICE%20PREDICTION.ipynb

# %% [markdown]
# # Loading test file

# %%
df1=pd.read_csv('housing_test.csv')

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2007        WD         Normal
# 1       0      8    2009       COD        Abnorml
# 2       0      6    2009        WD         Normal
# 3       0      7    2009        WD         Normal
# 4       0      1    2008        WD         Normal
#
# [5 rows x 80 columns]

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Doing all preprocessig steps same as training data

# %%
#checking shape of dataset
shape=df1.shape
print("\nTotal Number of Rows : ",shape[0])
print("Total Number of Features : ", shape[1])
# Out:
# Total Number of Rows :  292
# Total Number of Features :  80

# %%
#checking for null values
print(df1.isnull().values.any())
# Out:
# True

# %%
#Removing irrelevant features6
df1.drop(["Id"],axis=1,inplace=True)

# %%
#making seperate lists of categorical and continuos varioables
categorical=[x for x in df1.columns if df1[x].dtype==object]
cont=[x for x in df1.columns if x not in categorical]

# %%
len(cont)
# Out:
# 37

# %%
for i in categorical:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))
# Out:
# Alley: 95.21% missing values
# BsmtQual: 2.4% missing values
# BsmtCond: 2.4% missing values
# BsmtExposure: 2.4% missing values
# BsmtFinType1: 2.4% missing values
# BsmtFinType2: 2.4% missing values
# FireplaceQu: 47.6% missing values
# GarageType: 5.82% missing values
# GarageFinish: 5.82% missing values
# GarageQual: 5.82% missing values
# GarageCond: 5.82% missing values
# Fence: 84.93% missing values
# MiscFeature: 96.58% missing values

# %%
# For Alley, NA means No_alley_access. Let's replace NAs with 'No_alley_access'
df1['Alley'].fillna('No_alley_access',inplace=True)
print(df1['Alley'].value_counts())

basement=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']
#NA means No_Basement for all i in basement. Let's replace NAs with 'No_Basement'
for i in basement:
    df1[i].fillna('No_Basement',inplace=True)
    print(df1[i].value_counts())

# for FireplaceQu NA means no fireplace
df1['FireplaceQu'].fillna('No_fireplace',inplace=True)
print(df1['FireplaceQu'].value_counts())  

#for GarageType NA means no garage
garage=['GarageType','GarageFinish','GarageQual','GarageCond']
#NA means no_garage for all i in garage. Let's replace NAs with 'No_Basement'
for i in garage:
    df1[i].fillna('no_garage',inplace=True)
    print(df1[i].value_counts())

# As per given definition, NA means None. Let's replace NAs with 'None'
df1['MiscFeature'].fillna('None',inplace=True)
print(df1['MiscFeature'].value_counts())

# As per given definition, NA means No_Fence. Let's replace NAs with 'No_Fence'
df1['Fence'].fillna('No_Fence',inplace=True)
print(df1['Fence'].value_counts())
# Out:
# No_alley_access    278
# Grvl                 9
# Pave                 5
# Name: Alley, dtype: int64
# TA             132
# Gd             120
# Ex              27
# No_Basement      7
# Fa               6
# Name: BsmtQual, dtype: int64
# TA             270
# Gd               9
# No_Basement      7
# Fa               6
# Name: BsmtCond, dtype: int64
# No             197
# Av              41
# Gd              26
# Mn              21
# No_Basement      7
# Name: BsmtExposure, dtype: int64
# GLQ            88
# Unf            85
# ALQ            46
# BLQ            27
# Rec            24
# LwQ            15
# No_Basement     7
# Name: BsmtFinType1, dtype: int64
# Unf            254
# Rec             11
# BLQ              9
# No_Basement      7
# LwQ              6
# ALQ              3
# GLQ              2
# Name: BsmtFinType2, dtype: int64
# No_fireplace    139
# Gd               79
# TA               61
# Fa                8
# Ex                3
# Po                2
# Name: FireplaceQu, dtype: int64
# Attchd       179
# Detchd        73
# BuiltIn       18
# no_garage     17
# Basment        3
# CarPort        1
# 2Types         1
# Name: GarageType, dtype: int64
# Unf          118
# RFn           83
# Fin           74
# no_garage     17
# Name: GarageFinish, dtype: int64
# TA           261
# no_garage     17
# Fa             9
# Gd             3
# Ex             1
# Po             1
# Name: GarageQual, dtype: int64
# TA           265
# no_garage     17
# Fa             7
# Ex             1
# Po             1
# Gd             1
# Name: GarageCond, dtype: int64
# None    282
# Shed      9
# Othr      1
# Name: MiscFeature, dtype: int64
# No_Fence    248
# MnPrv        28
# GdPrv         8
# GdWo          7
# MnWw          1
# Name: Fence, dtype: int64

# %%
#NA means No_Fireplace. Let's replace NAs with 'No_Fireplace'
df1['FireplaceQu'].fillna('No_Fireplace',inplace=True)
print(df1['FireplaceQu'].value_counts())

garage=['GarageType','GarageFinish','GarageQual','GarageCond']
# NA means No_Garage for all i in garage
for i in garage:
    df1[i].fillna('No_Garage',inplace=True)
    print(df1[i].value_counts())
# Out:
# No_fireplace    139
# Gd               79
# TA               61
# Fa                8
# Ex                3
# Po                2
# Name: FireplaceQu, dtype: int64
# Attchd       179
# Detchd        73
# BuiltIn       18
# no_garage     17
# Basment        3
# CarPort        1
# 2Types         1
# Name: GarageType, dtype: int64
# Unf          118
# RFn           83
# Fin           74
# no_garage     17
# Name: GarageFinish, dtype: int64
# TA           261
# no_garage     17
# Fa             9
# Gd             3
# Ex             1
# Po             1
# Name: GarageQual, dtype: int64
# TA           265
# no_garage     17
# Fa             7
# Ex             1
# Po             1
# Gd             1
# Name: GarageCond, dtype: int64

# %%
#Again checking for missing value in,object dtype column
for i in categorical:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
for i in cont:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))
# Out:
# LotFrontage: 15.41% missing values
# GarageYrBlt: 5.82% missing values
# PoolQC: 100.0% missing values

# %%
#checking shape of dataset
shape=df1.shape
print("\nTotal Number of Rows : ",shape[0])
print("Total Number of Features : ", shape[1])

#checking for null values
print(df1.isnull().values.any())

#Removing irrelevant features6
df1.drop(["Id"],axis=1,inplace=True)

#making seperate lists of categorical and continuos varioables
categorical=[x for x in df1.columns if df1[x].dtype==object]
cont=[x for x in df1.columns if x not in categorical]

# For Alley, NA means No_alley_access. Let's replace NAs with 'No_alley_access'
df1['Alley'].fillna('No_alley_access',inplace=True)
print(df1['Alley'].value_counts())

basement=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']
#NA means No_Basement for all i in basement. Let's replace NAs with 'No_Basement'
for i in basement:
    df1[i].fillna('No_Basement',inplace=True)
    print(df1[i].value_counts())
    
    
# NA means No Pool. Let's replace NAs with 'No_Pool'
df1['PoolQC'].fillna('No_Pool',inplace=True)
print(df1['PoolQC'].value_counts())

# As per given definition, NA means None. Let's replace NAs with 'None'
df1['MiscFeature'].fillna('None',inplace=True)
print(df1['MiscFeature'].value_counts())

# As per given definition, NA means No_Fence. Let's replace NAs with 'No_Fence'
df1['Fence'].fillna('No_Fence',inplace=True)
print(df1['Fence'].value_counts())

#NA means No_Fireplace. Let's replace NAs with 'No_Fireplace'
df1['FireplaceQu'].fillna('No_Fireplace',inplace=True)
print(df1['FireplaceQu'].value_counts())

garage=['GarageType','GarageFinish','GarageQual','GarageCond']
# NA means No_Garage for all i in garage
for i in garage:
    df1[i].fillna('No_Garage',inplace=True)
    print(df1[i].value_counts())
    


for i in cont:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))
            
#filling missing data with imputation for numerical data
from sklearn.impute import SimpleImputer
# Out:
# Total Number of Rows :  292
# Total Number of Features :  79
# True
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-4b7e5d697965> in <module>
#       8
#       9 #Removing irrelevant features6
# ---> 10 df1.drop(["Id"],axis=1,inplace=True)
#      11
#      12 #making seperate lists of categorical and continuos varioables
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Id'] not found in axis"

# %%
#checking shape of dataset
shape=df1.shape
print("\nTotal Number of Rows : ",shape[0])
print("Total Number of Features : ", shape[1])

#checking for null values
print(df1.isnull().values.any())

#Removing irrelevant features6
df1.drop(["Id"],axis=1,inplace=True)

#making seperate lists of categorical and continuos varioables
categorical=[x for x in df1.columns if df1[x].dtype==object]
cont=[x for x in df1.columns if x not in categorical]

# For Alley, NA means No_alley_access. Let's replace NAs with 'No_alley_access'
df1['Alley'].fillna('No_alley_access',inplace=True)
print(df1['Alley'].value_counts())

basement=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']
#NA means No_Basement for all i in basement. Let's replace NAs with 'No_Basement'
for i in basement:
    df1[i].fillna('No_Basement',inplace=True)
    print(df1[i].value_counts())
    
    
# NA means No Pool. Let's replace NAs with 'No_Pool'
df1['PoolQC'].fillna('No_Pool',inplace=True)
print(df1['PoolQC'].value_counts())

# As per given definition, NA means None. Let's replace NAs with 'None'
df1['MiscFeature'].fillna('None',inplace=True)
print(df1['MiscFeature'].value_counts())

# As per given definition, NA means No_Fence. Let's replace NAs with 'No_Fence'
df1['Fence'].fillna('No_Fence',inplace=True)
print(df1['Fence'].value_counts())

#NA means No_Fireplace. Let's replace NAs with 'No_Fireplace'
df1['FireplaceQu'].fillna('No_Fireplace',inplace=True)
print(df1['FireplaceQu'].value_counts())

garage=['GarageType','GarageFinish','GarageQual','GarageCond']
# NA means No_Garage for all i in garage
for i in garage:
    df1[i].fillna('No_Garage',inplace=True)
    print(df1[i].value_counts())
    
df1['MasVnrType']=df1['MasVnrType'].fillna(df1['MasVnrType'].mode()[0])

for i in cont:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))
#filling missing data with imputation for numerical data
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values  = np.nan, strategy = 'mean')
for i in cont:
    df1[i]=imp.fit_transform(df1[i].values.reshape(-1,1))

# %%
for i in cont:
    if df1[i].isnull().sum()>1:
         print("{}: {}% missing values".format(i, round(df1[i].isnull().sum() * 100/len(df1[i]),2)))

# %%
#Removing irrelevant features6
df1.drop(["Utilities","PoolQC"],axis=1,inplace=True)

# %%
#dropping least correlated column
df1.drop(['MSSubClass' ,'OverallCond' ,'OverallCond' ,'LowQualFinSF' ,'BsmtHalfBath' ,'YrSold', 'MiscVal', 'MoSold', '3SsnPorch'],axis=1,inplace=True)

# %%
#creating new categorical and cont variable list and label encoding the categorical columns

categorical=[x for x in df1.columns if df1[x].dtype==object]
cont=[x for x in df1.columns if x not in categorical]

# %%
#filling missing data with imputation for numerical data
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values  = np.nan, strategy = 'mean')
for i in cont:
    df1[i]=imp.fit_transform(df1[i].values.reshape(-1,1))
